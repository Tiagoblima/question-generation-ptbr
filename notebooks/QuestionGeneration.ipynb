# %% [markdown]
# # Authentication

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !rm -rf /content/question-generation-ptbr
# !git clone https://github.com/Tiagoblima/question-generation-ptbr.git
# %cd /content/question-generation-ptbr
# !pip install --quiet -r requirements.txt
# Out:
# /content
# Cloning into 'question-generation-ptbr'...
# remote: Enumerating objects: 1316, done.
# remote: Counting objects: 100% (781/781), done.
# remote: Compressing objects: 100% (350/350), done.
# remote: Total 1316 (delta 467), reused 656 (delta 431), pack-reused 535
# Receiving objects: 100% (1316/1316), 207.69 KiB | 2.60 MiB/s, done.
# Resolving deltas: 100% (816/816), done.
# /content/question-generation-ptbr
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.0 MB/s eta 0:00:00
# ...

# %%
# %cd /content/question-generation-ptbr
# !git checkout exps
# !git pull origin exps
# Out:
# [Errno 2] No such file or directory: '/content/question-generation-ptbr'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd /content/question-generation-ptbr
# !echo   "export WANDB_API_KEY=8e593ae9d0788bae2e0a84d07de0e76f5cf3dcf4"  > run_setup.sh
# !echo   "export HF_TOKEN=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" >> run_setup.sh
# !echo   "export WANDB_PROJECT=question-generation-ptbr \n" >> run_setup.sh
#!echo   "export WANDB_MODE=disabled" >> run_setup.sh
# !echo   "source scripts/run_train.sh experiments/answer-paragraph/t5_base-qg-ap-nopeft.json" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/t5_base-qg-ap-nopeft paragraph,answer" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/t5_large-qg-aap paragraph_answer" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/t5_large-qg-aas answer_sentence" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/t5_large-qg-af paragraph_sentence" >> run_setup.sh

# !echo   "source scripts/run_eval.sh tiagoblima/mbart50-qg-aap paragraph_answer" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/mbart50-qg-aas answer_sentence" >> run_setup.sh
# !echo   "source scripts/run_eval.sh tiagoblima/mbart50-qg-af paragraph_sentence" >> run_setup.sh
# Out:
# [Errno 2] No such file or directory: '/content/question-generation-ptbr'
# /content

# %%
# %cd /content/question-generation-ptbr
# !git stash
# !git checkout eval
# !git pull origin eval
# !bash run_setup.sh
# Out:
# [Errno 2] No such file or directory: '/content/question-generation-ptbr'
# /content
# run_setup.sh: line 4: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 5: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 6: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 7: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 8: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 9: scripts/run_eval.sh: No such file or directory
# run_setup.sh: line 10: scripts/run_eval.sh: No such file or directory
